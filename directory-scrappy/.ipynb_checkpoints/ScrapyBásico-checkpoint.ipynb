# %% [markdown]
# # Web Scraping with Python and BeautifulSoup

# %%
# Instalación de librerías
#!pip3 install

# %%
# Librerías básicas

import requests  # To connect to the page we want to scrape from
import bs4
from bs4 import BeautifulSoup # Provides a collection of functions that simplify scraping
import pandas as pd # To manage our data
import json

# %% [markdown]
# ## Extracción de datos desde la página principal de la UTPL

# %%
# Page encoding
page = requests.get("https://www.utpl.edu.ec/directorio/index.php?"+ \
"ban=1&id_dep=18&id_citte=18&bandera=0&nom_dep=VICERRECTORADO%20ACADÉMICO")
page.encoding = "utf-8"
page # Print status. 200 is OK
# Out:
# <Response [200]>

# %%
web = input()
resp_get = requests.get(web)
resp_get.encoding = "utf-8"
resp_get
# Out:
# https://www.utpl.edu.ec/directorio/index.php?ban=1&id_citte=18&id_dep=275&nom_dep=COORDINACIÓN%20GENERAL
# <Response [200]>

# %%
# To parse the page's text
soup = BeautifulSoup(resp_get.text, "html.parser")

# Print HTMl DOC
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta content="text/html;&gt;
#   &lt;/head&gt;
#     &lt;head&gt;
#         &lt;title&gt;Contactos UTPL&lt;/title&gt;
#         &lt;link rel=" href="images/favicon.ico" http-equiv="content-type" icon"="" shortcut=""/>
# <script src="http://css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script>
# <meta content="width=device-width" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <script src="js/jquery.min.js"></script>
# <link href="css/estilos.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# <!-- Optional theme -->
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap-theme.min.css" integrity="sha384-rHyoN1iRsVXV4nD0JutlnGaslCJuC7uwjduW9SVrLvRYooPp2bWYgmgJQIXwl/Sp" rel="stylesheet"/>
# <!-- Latest compiled and minified JavaScript -->
# <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
# <!--        <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css">
#         <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css">
#         <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>-->
# <script src="js/validator.min.js"></script>
# <script src="js/main.js"></script>
# <script type="text/javascript">
#     (function(c,l,a,r,i,t,y){
#         c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#         t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#         y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);
#     })(window, document, "clarity", "script", "crqt5w5ynt");
# </script>
# </meta></head>
# <body class="template">
# <header class="header_template">
# <div class="wrap">
# <div class="container_header">
# <div id="logo">
# <a href="http://www.utpl.edu.ec" target="_blank"><img src="http://www.utpl.edu.ec/sites/all/themes/utpl/images/logo.png"/></a>
# </div>
# <div id="name">
# <label class="label_template">CONTACTOS</label>
# </div>
# </div>
# </div>
# <a href="https://www.facebook.com/utpl.loja" target="_blank"><div class="ventana_flotante1"></div></a>
# <a href="https://twitter.com/utpl" target="_blank"><div class="ventana_flotante2"></div></a>
# <a href="https://plus.google.com/102948673709127621886" target="_blank"><div class="ventana_flotante3"></div></a>
# <a href="https://instagram.com/utpl" target="_blank"><div class="ventana_flotante4"></div></a>
# <a href="https://www.flickr.com/photos/utpl" target="_blank"><div class="ventana_flotante5"></div></a>
# <a href="https://www.youtube.com/user/utpl" target="_blank"><div class="ventana_flotante6"></div></a>
# </header>
# <nav class="nav_template">
# <div class="wrap">
# <div class="container_options_nav">
# <!--<a href="http://www.utpl.edu.ec/directorio/directorio/"><img src="images/home.jpg"></a>-->
# <ul id="menu">
# <li><a href="http://www.utpl.edu.ec/directorio"><img src="images/home.jpg"/></a></li>
# <li><a class="mainmenu" href="index.php?ban=1">Vicerrectorados y Direcciones Generales</a></li>
# <li><a class="mainmenu" href="index.php?ban=2">Facultades, Departamentos y Unidades</a></li>
# <li><a class="mainmenu" href="index.php?ban=3">Carreras y Posgrados</a></li>
# <li><a class="mainmenu" href="index.php?ban=4">Unidades</a></li>
# <li><a class="mainmenu" href="index.php?ban=5">Guía general</a></li>
# <li><a class="mainmenu" href="index.php?ban=6">Sección alfabética</a></li>
# <li><a class="mainmenu" href="http://www.utpl.edu.ec/centros_utpl/">Centros Universitarios</a></li>
# </ul> </div>
# </div>
# </nav>
# <section class="section_template">
# <table align="center" border="0" cellpadding="0" cellspacing="3" width="99%">
# <tr>
# <td class="borde justificado" valign="top" width="49%"><p>
# <ul class="vinetas"><li class="area7"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=7&amp;id_citte=7&amp;bandera=0&amp;nom_dep=COORDINACIÓN DE CÁTEDRAS UNESCO - UTPL">COORDINACIÓN DE CÁTEDRAS UNESCO - UTPL</a></li><li class="area8"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=8&amp;id_citte=8&amp;bandera=0&amp;nom_dep=DIRECCIÓN DE COMUNICACIÓN Y MARKETING">DIRECCIÓN DE COMUNICACIÓN Y MARKETING</a></li><li class="area9"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=9&amp;id_citte=9&amp;bandera=0&amp;nom_dep=DIRECCIÓN DE EVALUACIÓN INSTITUCIONAL">DIRECCIÓN DE EVALUACIÓN INSTITUCIONAL</a></li><li class="area10"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=10&amp;id_citte=10&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE TI Y TRANSFORMACIÓN DIGITAL">DIRECCIÓN GENERAL DE TI Y TRANSFORMACIÓN DIGITAL</a></li><li class="area11"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=11&amp;id_citte=11&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE MISIONES UNIVERSITARIAS">DIRECCIÓN GENERAL DE MISIONES UNIVERSITARIAS</a></li><li class="area12"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=12&amp;id_citte=12&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE PROYECCIÓN Y DESARROLLO INSTITUCIONAL">DIRECCIÓN GENERAL DE PROYECCIÓN Y DESARROLLO INSTITUCIONAL</a></li><li class="area13"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=13&amp;id_citte=13&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE RELACIONES INTERINSTITUCIONALES">DIRECCIÓN GENERAL DE RELACIONES INTERINSTITUCIONALES</a></li><li class="area14"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=14&amp;id_citte=14&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE VINCULACIÓN CON LA SOCIEDAD">DIRECCIÓN GENERAL DE VINCULACIÓN CON LA SOCIEDAD</a></li><li class="area16"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=16&amp;id_citte=16&amp;bandera=0&amp;nom_dep=PROCURADURÍA UNIVERSITARIA">PROCURADURÍA UNIVERSITARIA</a></li><li class="area17"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=17&amp;id_citte=17&amp;bandera=0&amp;nom_dep=SECRETARIA GENERAL">SECRETARIA GENERAL</a></li><li class="area18"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=18&amp;id_citte=18&amp;bandera=0&amp;nom_dep=VICERRECTORADO ACADÉMICO">VICERRECTORADO ACADÉMICO</a></li><ul class="vinetas"><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=275&amp;nom_dep=COORDINACIÓN GENERAL">COORDINACIÓN GENERAL</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=276&amp;nom_dep=DIRECCIÓN DE INNOVACIÓN FORMACIÓN Y EVALUACIÓN DOCENTE">DIRECCIÓN DE INNOVACIÓN FORMACIÓN Y EVALUACIÓN DOCENTE</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=277&amp;nom_dep=DIRECCIÓN DE PLANIFICACIÓN Y DESARROLLO DEL CURRÍCULO">DIRECCIÓN DE PLANIFICACIÓN Y DESARROLLO DEL CURRÍCULO</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=278&amp;nom_dep=DIRECCIÓN DE POSTGRADOS">DIRECCIÓN DE POSTGRADOS</a></li></ul><li class="area19"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=19&amp;id_citte=19&amp;bandera=0&amp;nom_dep=VICERRECTORADO ADMINISTRATIVO">VICERRECTORADO ADMINISTRATIVO</a></li><li class="area20"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=20&amp;id_citte=20&amp;bandera=0&amp;nom_dep=VICERRECTORADO DE INVESTIGACIÓN">VICERRECTORADO DE INVESTIGACIÓN</a></li><li class="area21"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=21&amp;id_citte=21&amp;bandera=0&amp;nom_dep=VICERRECTORADO DE MODALIDAD ABIERTA Y A DISTANCIA">VICERRECTORADO DE MODALIDAD ABIERTA Y A DISTANCIA</a></li><li class="area22"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=22&amp;id_citte=22&amp;bandera=0&amp;nom_dep=RECTORADO">RECTORADO</a></li></ul> </p></td>
# <td valign="top" width="51%"><table align="center" border="0" cellpadding="0" cellspacing="2" width="98%">
# <tr>
# <td class="borde"><div class="scroll">
# <div class="titulos_amarillos2">COORDINACIÓN GENERAL</div>
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td bgcolor="#ffffff" class="texto_normal"><span class="letra_nombre">Andrade Abarca Paola Salome, Mgtr. </span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"> Coordinadora General Académica</img></span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"> psandrade@utpl.edu.ec</img></span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2395</span></td></tr><tr><td bgcolor="#E8EEFD" class="texto_normal"><span class="letra_nombre">Gomez Flores Bryan Israel, Ing.</span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista De Seguimiento A Casos Especiales De Estudiantes</span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> bigomez@utpl.edu.ec</span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2286</span></td></tr><tr><td bgcolor="#ffffff" class="texto_normal"><span class="letra_nombre">Torres Valarezo Juliana Fernanda, Mgtr. </span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista De Admisiones De Grado</span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> jvtorres@utpl.edu.ec</span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 3075</span></td></tr></table></div></td>
# </tr>
# </table></td>
# </tr>
# </table>
# <p> </p>
# </section>
# <footer class="footer_template">
# <div class="wrap">
# <div class="info_u">
# <table class="table_template">
# <tr>
# <td>
# <div class="cont_icon">
# <img class="img_template" src="images/telef.png"/>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									07 370 1444
# 								</div>
# <div class="txt_info">
# 									Comunícate con nuestros<br/>
# 									Docentes y Personal UTPL
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="http://www.utpl.edu.ec/buzon/" id="url_img" target="_blank"><img class="img_template" src="images/print.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Buzón de consultas
# 								</div>
# <div class="txt_info">
# 									Escríbenos a nuestro buzón y recibe una completa información de trámites y servicios UTPL.
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="http://www.utpl.edu.ec/centros_utpl/" id="url_img" target="_blank"><img class="img_template" src="images/marcador.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Centros UTPL
# 								</div>
# <div class="txt_info">
# 									Conoce el centro UTPL más cercano.
# 								</div>
# </div>
# </td>
# </tr>
# <tr>
# <td>
# <div class="cont_icon">
# <img class="img_template" src="images/audif.png"/>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									1800 8875 88
# 								</div>
# <div class="txt_info">
# 									En la línea gratuita 1800 podrás tener información de la oferta académica.
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="https://tramites.utpl.edu.ec" id="url_img" target="_blank"><img class="img_template" src="images/mouse.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Trámites académicos en línea
# 								</div>
# <div class="txt_info">
# 									Recuerda puedes ingresar tu Trámite académico en línea <a href="http://bit.ly/trámitesenlínea" id="url" target="_blank">http://bit.ly/trámitesenlínea</a><br/>
# </div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="#" id="url_img" target="_blank"><img class="img_template" src="images/app-movil.png" style="width:50px !important"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									App UTPL
# 								</div>
# <div class="txt_info">
# 									Descárgala en App Store para dispositivos iOS y en Google Play para Android.<br/>
# </div>
# </div>
# </td>
# <!--<td>
# 							<div class="cont_icon">
# 								<a href="http://www.utpl.edu.ec/academia/ebooks" id="url_img" target="_blank"><img src="images/ebook.png" class="img_template"></a>
# 							</div>
# 							<div class="cont_txt">
# 								<div class="txt_titulo">
# 									Soporte técnico para Ebooks y Tablets
# 								</div>
# 								<div class="txt_info">
# 									Comunícate con nosotros al 07 3701444<br> ext.: 3200 o escríbenos a ebooks@utpl.edu.ec<br>
# 								</div>
# 							</div>
# 						</td>-->
# </tr>
# </table>
# </div> </div>
# </footer>
# <footer class="subfooter">
# <div class="wrap">
# <p id="txt_subfoot">Sede Central Loja: el personal UTPL puede consultar la guía de usuario del servicio de comunicaciones unificadas en: <a href="http://bit.ly/1s4hUvW" id="lnk_guia" target="_blank">http://bit.ly/1s4hUvW.</a></p>
# </div>
# </footer>
# </body>
# </html>

# %%
# Print title
print(soup.find("div", {"class"="titulos_amarillos2"}))
title=soup.find("div", {"class"="titulos_amarillos2"}
# Out:
# <div class="wrap">
# <div class="container_header">
# <div id="logo">
# <a href="http://www.utpl.edu.ec" target="_blank"><img src="http://www.utpl.edu.ec/sites/all/themes/utpl/images/logo.png"/></a>
# </div>
# <div id="name">
# <label class="label_template">CONTACTOS</label>
# </div>
# </div>
# </div>

# %%
# Print the page body
print(soup.body)
# Out:
# <body class="template">
# <header class="header_template">
# <div class="wrap">
# <div class="container_header">
# <div id="logo">
# <a href="http://www.utpl.edu.ec" target="_blank"><img src="http://www.utpl.edu.ec/sites/all/themes/utpl/images/logo.png"/></a>
# </div>
# <div id="name">
# <label class="label_template">CONTACTOS</label>
# </div>
# </div>
# </div>
# <a href="https://www.facebook.com/utpl.loja" target="_blank"><div class="ventana_flotante1"></div></a>
# <a href="https://twitter.com/utpl" target="_blank"><div class="ventana_flotante2"></div></a>
# <a href="https://plus.google.com/102948673709127621886" target="_blank"><div class="ventana_flotante3"></div></a>
# <a href="https://instagram.com/utpl" target="_blank"><div class="ventana_flotante4"></div></a>
# <a href="https://www.flickr.com/photos/utpl" target="_blank"><div class="ventana_flotante5"></div></a>
# <a href="https://www.youtube.com/user/utpl" target="_blank"><div class="ventana_flotante6"></div></a>
# </header>
# <nav class="nav_template">
# <div class="wrap">
# <div class="container_options_nav">
# <!--<a href="http://www.utpl.edu.ec/directorio/directorio/"><img src="images/home.jpg"></a>-->
# <ul id="menu">
# <li><a href="http://www.utpl.edu.ec/directorio"><img src="images/home.jpg"/></a></li>
# <li><a class="mainmenu" href="index.php?ban=1">Vicerrectorados y Direcciones Generales</a></li>
# <li><a class="mainmenu" href="index.php?ban=2">Facultades, Departamentos y Unidades</a></li>
# <li><a class="mainmenu" href="index.php?ban=3">Carreras y Posgrados</a></li>
# <li><a class="mainmenu" href="index.php?ban=4">Unidades</a></li>
# <li><a class="mainmenu" href="index.php?ban=5">Guía general</a></li>
# <li><a class="mainmenu" href="index.php?ban=6">Sección alfabética</a></li>
# <li><a class="mainmenu" href="http://www.utpl.edu.ec/centros_utpl/">Centros Universitarios</a></li>
# </ul> </div>
# </div>
# </nav>
# <section class="section_template">
# <table align="center" border="0" cellpadding="0" cellspacing="3" width="99%">
# <tr>
# <td class="borde justificado" valign="top" width="49%"><p>
# <ul class="vinetas"><li class="area7"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=7&amp;id_citte=7&amp;bandera=0&amp;nom_dep=COORDINACIÓN DE CÁTEDRAS UNESCO - UTPL">COORDINACIÓN DE CÁTEDRAS UNESCO - UTPL</a></li><li class="area8"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=8&amp;id_citte=8&amp;bandera=0&amp;nom_dep=DIRECCIÓN DE COMUNICACIÓN Y MARKETING">DIRECCIÓN DE COMUNICACIÓN Y MARKETING</a></li><li class="area9"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=9&amp;id_citte=9&amp;bandera=0&amp;nom_dep=DIRECCIÓN DE EVALUACIÓN INSTITUCIONAL">DIRECCIÓN DE EVALUACIÓN INSTITUCIONAL</a></li><li class="area10"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=10&amp;id_citte=10&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE TI Y TRANSFORMACIÓN DIGITAL">DIRECCIÓN GENERAL DE TI Y TRANSFORMACIÓN DIGITAL</a></li><li class="area11"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=11&amp;id_citte=11&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE MISIONES UNIVERSITARIAS">DIRECCIÓN GENERAL DE MISIONES UNIVERSITARIAS</a></li><li class="area12"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=12&amp;id_citte=12&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE PROYECCIÓN Y DESARROLLO INSTITUCIONAL">DIRECCIÓN GENERAL DE PROYECCIÓN Y DESARROLLO INSTITUCIONAL</a></li><li class="area13"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=13&amp;id_citte=13&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE RELACIONES INTERINSTITUCIONALES">DIRECCIÓN GENERAL DE RELACIONES INTERINSTITUCIONALES</a></li><li class="area14"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=14&amp;id_citte=14&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE VINCULACIÓN CON LA SOCIEDAD">DIRECCIÓN GENERAL DE VINCULACIÓN CON LA SOCIEDAD</a></li><li class="area16"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=16&amp;id_citte=16&amp;bandera=0&amp;nom_dep=PROCURADURÍA UNIVERSITARIA">PROCURADURÍA UNIVERSITARIA</a></li><li class="area17"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=17&amp;id_citte=17&amp;bandera=0&amp;nom_dep=SECRETARIA GENERAL">SECRETARIA GENERAL</a></li><li class="area18"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=18&amp;id_citte=18&amp;bandera=0&amp;nom_dep=VICERRECTORADO ACADÉMICO">VICERRECTORADO ACADÉMICO</a></li><ul class="vinetas"><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=275&amp;nom_dep=COORDINACIÓN GENERAL">COORDINACIÓN GENERAL</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=276&amp;nom_dep=DIRECCIÓN DE INNOVACIÓN FORMACIÓN Y EVALUACIÓN DOCENTE">DIRECCIÓN DE INNOVACIÓN FORMACIÓN Y EVALUACIÓN DOCENTE</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=277&amp;nom_dep=DIRECCIÓN DE PLANIFICACIÓN Y DESARROLLO DEL CURRÍCULO">DIRECCIÓN DE PLANIFICACIÓN Y DESARROLLO DEL CURRÍCULO</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=278&amp;nom_dep=DIRECCIÓN DE POSTGRADOS">DIRECCIÓN DE POSTGRADOS</a></li></ul><li class="area19"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=19&amp;id_citte=19&amp;bandera=0&amp;nom_dep=VICERRECTORADO ADMINISTRATIVO">VICERRECTORADO ADMINISTRATIVO</a></li><li class="area20"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=20&amp;id_citte=20&amp;bandera=0&amp;nom_dep=VICERRECTORADO DE INVESTIGACIÓN">VICERRECTORADO DE INVESTIGACIÓN</a></li><li class="area21"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=21&amp;id_citte=21&amp;bandera=0&amp;nom_dep=VICERRECTORADO DE MODALIDAD ABIERTA Y A DISTANCIA">VICERRECTORADO DE MODALIDAD ABIERTA Y A DISTANCIA</a></li><li class="area22"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=22&amp;id_citte=22&amp;bandera=0&amp;nom_dep=RECTORADO">RECTORADO</a></li></ul> </p></td>
# <td valign="top" width="51%"><table align="center" border="0" cellpadding="0" cellspacing="2" width="98%">
# <tr>
# <td class="borde"><div class="scroll">
# <div class="titulos_amarillos2">COORDINACIÓN GENERAL</div>
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td bgcolor="#ffffff" class="texto_normal"><span class="letra_nombre">Andrade Abarca Paola Salome, Mgtr. </span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"> Coordinadora General Académica</img></span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"> psandrade@utpl.edu.ec</img></span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2395</span></td></tr><tr><td bgcolor="#E8EEFD" class="texto_normal"><span class="letra_nombre">Gomez Flores Bryan Israel, Ing.</span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista De Seguimiento A Casos Especiales De Estudiantes</span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> bigomez@utpl.edu.ec</span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2286</span></td></tr><tr><td bgcolor="#ffffff" class="texto_normal"><span class="letra_nombre">Torres Valarezo Juliana Fernanda, Mgtr. </span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista De Admisiones De Grado</span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> jvtorres@utpl.edu.ec</span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 3075</span></td></tr></table></div></td>
# </tr>
# </table></td>
# </tr>
# </table>
# <p> </p>
# </section>
# <footer class="footer_template">
# <div class="wrap">
# <div class="info_u">
# <table class="table_template">
# <tr>
# <td>
# <div class="cont_icon">
# <img class="img_template" src="images/telef.png"/>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									07 370 1444
# 								</div>
# <div class="txt_info">
# 									Comunícate con nuestros<br/>
# 									Docentes y Personal UTPL
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="http://www.utpl.edu.ec/buzon/" id="url_img" target="_blank"><img class="img_template" src="images/print.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Buzón de consultas
# 								</div>
# <div class="txt_info">
# 									Escríbenos a nuestro buzón y recibe una completa información de trámites y servicios UTPL.
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="http://www.utpl.edu.ec/centros_utpl/" id="url_img" target="_blank"><img class="img_template" src="images/marcador.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Centros UTPL
# 								</div>
# <div class="txt_info">
# 									Conoce el centro UTPL más cercano.
# 								</div>
# </div>
# </td>
# </tr>
# <tr>
# <td>
# <div class="cont_icon">
# <img class="img_template" src="images/audif.png"/>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									1800 8875 88
# 								</div>
# <div class="txt_info">
# 									En la línea gratuita 1800 podrás tener información de la oferta académica.
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="https://tramites.utpl.edu.ec" id="url_img" target="_blank"><img class="img_template" src="images/mouse.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Trámites académicos en línea
# 								</div>
# <div class="txt_info">
# 									Recuerda puedes ingresar tu Trámite académico en línea <a href="http://bit.ly/trámitesenlínea" id="url" target="_blank">http://bit.ly/trámitesenlínea</a><br/>
# </div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="#" id="url_img" target="_blank"><img class="img_template" src="images/app-movil.png" style="width:50px !important"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									App UTPL
# 								</div>
# <div class="txt_info">
# 									Descárgala en App Store para dispositivos iOS y en Google Play para Android.<br/>
# </div>
# </div>
# </td>
# <!--<td>
# 							<div class="cont_icon">
# 								<a href="http://www.utpl.edu.ec/academia/ebooks" id="url_img" target="_blank"><img src="images/ebook.png" class="img_template"></a>
# 							</div>
# 							<div class="cont_txt">
# 								<div class="txt_titulo">
# 									Soporte técnico para Ebooks y Tablets
# 								</div>
# 								<div class="txt_info">
# 									Comunícate con nosotros al 07 3701444<br> ext.: 3200 o escríbenos a ebooks@utpl.edu.ec<br>
# 								</div>
# 							</div>
# 						</td>-->
# </tr>
# </table>
# </div> </div>
# </footer>
# <footer class="subfooter">
# <div class="wrap">
# <p id="txt_subfoot">Sede Central Loja: el personal UTPL puede consultar la guía de usuario del servicio de comunicaciones unificadas en: <a href="http://bit.ly/1s4hUvW" id="lnk_guia" target="_blank">http://bit.ly/1s4hUvW.</a></p>
# </div>
# </footer>
# </body>

# %%
print(soup.body.table.div)
# Out:
# <div class="scroll">
# <div class="titulos_amarillos2">COORDINACIÓN GENERAL</div>
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td bgcolor="#ffffff" class="texto_normal"><span class="letra_nombre">Andrade Abarca Paola Salome, Mgtr. </span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"> Coordinadora General Académica</img></span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"> psandrade@utpl.edu.ec</img></span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2395</span></td></tr><tr><td bgcolor="#E8EEFD" class="texto_normal"><span class="letra_nombre">Gomez Flores Bryan Israel, Ing.</span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista De Seguimiento A Casos Especiales De Estudiantes</span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> bigomez@utpl.edu.ec</span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2286</span></td></tr><tr><td bgcolor="#ffffff" class="texto_normal"><span class="letra_nombre">Torres Valarezo Juliana Fernanda, Mgtr. </span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista De Admisiones De Grado</span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> jvtorres@utpl.edu.ec</span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 3075</span></td></tr></table></div>

# %%
# Filtering content: 
# find all div tags with field-items class.

json_f = {}

items = soup.find("span", {"class": "letra_info"}).next;
len(items) # 73 div tags in the page
items
# Out:
# <img height="19" src="images/dep.gif" width="17"> Coordinadora General Académica</img>

# %%
for i in soup:
    soup.find("span", {"class": "letra_info"}).next
    print(i)
# Out:
# html
#
#
# <html lang="es">
# <head>
# <meta content="text/html;&gt;
#   &lt;/head&gt;
#     &lt;head&gt;
#         &lt;title&gt;Contactos UTPL&lt;/title&gt;
#         &lt;link rel=" href="images/favicon.ico" http-equiv="content-type" icon"="" shortcut=""/>
# <script src="http://css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script>
# <meta content="width=device-width" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <script src="js/jquery.min.js"></script>
# <link href="css/estilos.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
# <!-- Optional theme -->
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap-theme.min.css" integrity="sha384-rHyoN1iRsVXV4nD0JutlnGaslCJuC7uwjduW9SVrLvRYooPp2bWYgmgJQIXwl/Sp" rel="stylesheet"/>
# <!-- Latest compiled and minified JavaScript -->
# <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
# <!--        <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css">
#         <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css">
#         <script src="//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js"></script>-->
# <script src="js/validator.min.js"></script>
# <script src="js/main.js"></script>
# <script type="text/javascript">
#     (function(c,l,a,r,i,t,y){
#         c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#         t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#         y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);
#     })(window, document, "clarity", "script", "crqt5w5ynt");
# </script>
# </meta></head>
# <body class="template">
# <header class="header_template">
# <div class="wrap">
# <div class="container_header">
# <div id="logo">
# <a href="http://www.utpl.edu.ec" target="_blank"><img src="http://www.utpl.edu.ec/sites/all/themes/utpl/images/logo.png"/></a>
# </div>
# <div id="name">
# <label class="label_template">CONTACTOS</label>
# </div>
# </div>
# </div>
# <a href="https://www.facebook.com/utpl.loja" target="_blank"><div class="ventana_flotante1"></div></a>
# <a href="https://twitter.com/utpl" target="_blank"><div class="ventana_flotante2"></div></a>
# <a href="https://plus.google.com/102948673709127621886" target="_blank"><div class="ventana_flotante3"></div></a>
# <a href="https://instagram.com/utpl" target="_blank"><div class="ventana_flotante4"></div></a>
# <a href="https://www.flickr.com/photos/utpl" target="_blank"><div class="ventana_flotante5"></div></a>
# <a href="https://www.youtube.com/user/utpl" target="_blank"><div class="ventana_flotante6"></div></a>
# </header>
# <nav class="nav_template">
# <div class="wrap">
# <div class="container_options_nav">
# <!--<a href="http://www.utpl.edu.ec/directorio/directorio/"><img src="images/home.jpg"></a>-->
# <ul id="menu">
# <li><a href="http://www.utpl.edu.ec/directorio"><img src="images/home.jpg"/></a></li>
# <li><a class="mainmenu" href="index.php?ban=1">Vicerrectorados y Direcciones Generales</a></li>
# <li><a class="mainmenu" href="index.php?ban=2">Facultades, Departamentos y Unidades</a></li>
# <li><a class="mainmenu" href="index.php?ban=3">Carreras y Posgrados</a></li>
# <li><a class="mainmenu" href="index.php?ban=4">Unidades</a></li>
# <li><a class="mainmenu" href="index.php?ban=5">Guía general</a></li>
# <li><a class="mainmenu" href="index.php?ban=6">Sección alfabética</a></li>
# <li><a class="mainmenu" href="http://www.utpl.edu.ec/centros_utpl/">Centros Universitarios</a></li>
# </ul> </div>
# </div>
# </nav>
# <section class="section_template">
# <table align="center" border="0" cellpadding="0" cellspacing="3" width="99%">
# <tr>
# <td class="borde justificado" valign="top" width="49%"><p>
# <ul class="vinetas"><li class="area7"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=7&amp;id_citte=7&amp;bandera=0&amp;nom_dep=COORDINACIÓN DE CÁTEDRAS UNESCO - UTPL">COORDINACIÓN DE CÁTEDRAS UNESCO - UTPL</a></li><li class="area8"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=8&amp;id_citte=8&amp;bandera=0&amp;nom_dep=DIRECCIÓN DE COMUNICACIÓN Y MARKETING">DIRECCIÓN DE COMUNICACIÓN Y MARKETING</a></li><li class="area9"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=9&amp;id_citte=9&amp;bandera=0&amp;nom_dep=DIRECCIÓN DE EVALUACIÓN INSTITUCIONAL">DIRECCIÓN DE EVALUACIÓN INSTITUCIONAL</a></li><li class="area10"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=10&amp;id_citte=10&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE TI Y TRANSFORMACIÓN DIGITAL">DIRECCIÓN GENERAL DE TI Y TRANSFORMACIÓN DIGITAL</a></li><li class="area11"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=11&amp;id_citte=11&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE MISIONES UNIVERSITARIAS">DIRECCIÓN GENERAL DE MISIONES UNIVERSITARIAS</a></li><li class="area12"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=12&amp;id_citte=12&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE PROYECCIÓN Y DESARROLLO INSTITUCIONAL">DIRECCIÓN GENERAL DE PROYECCIÓN Y DESARROLLO INSTITUCIONAL</a></li><li class="area13"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=13&amp;id_citte=13&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE RELACIONES INTERINSTITUCIONALES">DIRECCIÓN GENERAL DE RELACIONES INTERINSTITUCIONALES</a></li><li class="area14"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=14&amp;id_citte=14&amp;bandera=0&amp;nom_dep=DIRECCIÓN GENERAL DE VINCULACIÓN CON LA SOCIEDAD">DIRECCIÓN GENERAL DE VINCULACIÓN CON LA SOCIEDAD</a></li><li class="area16"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=16&amp;id_citte=16&amp;bandera=0&amp;nom_dep=PROCURADURÍA UNIVERSITARIA">PROCURADURÍA UNIVERSITARIA</a></li><li class="area17"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=17&amp;id_citte=17&amp;bandera=0&amp;nom_dep=SECRETARIA GENERAL">SECRETARIA GENERAL</a></li><li class="area18"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=18&amp;id_citte=18&amp;bandera=0&amp;nom_dep=VICERRECTORADO ACADÉMICO">VICERRECTORADO ACADÉMICO</a></li><ul class="vinetas"><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=275&amp;nom_dep=COORDINACIÓN GENERAL">COORDINACIÓN GENERAL</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=276&amp;nom_dep=DIRECCIÓN DE INNOVACIÓN FORMACIÓN Y EVALUACIÓN DOCENTE">DIRECCIÓN DE INNOVACIÓN FORMACIÓN Y EVALUACIÓN DOCENTE</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=277&amp;nom_dep=DIRECCIÓN DE PLANIFICACIÓN Y DESARROLLO DEL CURRÍCULO">DIRECCIÓN DE PLANIFICACIÓN Y DESARROLLO DEL CURRÍCULO</a></li><li><a class="linkvinieta" href="index.php?ban=1&amp;id_citte=18&amp;id_dep=278&amp;nom_dep=DIRECCIÓN DE POSTGRADOS">DIRECCIÓN DE POSTGRADOS</a></li></ul><li class="area19"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=19&amp;id_citte=19&amp;bandera=0&amp;nom_dep=VICERRECTORADO ADMINISTRATIVO">VICERRECTORADO ADMINISTRATIVO</a></li><li class="area20"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=20&amp;id_citte=20&amp;bandera=0&amp;nom_dep=VICERRECTORADO DE INVESTIGACIÓN">VICERRECTORADO DE INVESTIGACIÓN</a></li><li class="area21"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=21&amp;id_citte=21&amp;bandera=0&amp;nom_dep=VICERRECTORADO DE MODALIDAD ABIERTA Y A DISTANCIA">VICERRECTORADO DE MODALIDAD ABIERTA Y A DISTANCIA</a></li><li class="area22"><a class="linkvinieta" href="index.php?ban=1&amp;id_dep=22&amp;id_citte=22&amp;bandera=0&amp;nom_dep=RECTORADO">RECTORADO</a></li></ul> </p></td>
# <td valign="top" width="51%"><table align="center" border="0" cellpadding="0" cellspacing="2" width="98%">
# <tr>
# <td class="borde"><div class="scroll">
# <div class="titulos_amarillos2">COORDINACIÓN GENERAL</div>
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td bgcolor="#ffffff" class="texto_normal"><span class="letra_nombre">Andrade Abarca Paola Salome, Mgtr. </span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"> Coordinadora General Académica</img></span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"> psandrade@utpl.edu.ec</img></span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2395</span></td></tr><tr><td bgcolor="#E8EEFD" class="texto_normal"><span class="letra_nombre">Gomez Flores Bryan Israel, Ing.</span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista De Seguimiento A Casos Especiales De Estudiantes</span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> bigomez@utpl.edu.ec</span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2286</span></td></tr><tr><td bgcolor="#ffffff" class="texto_normal"><span class="letra_nombre">Torres Valarezo Juliana Fernanda, Mgtr. </span><br/><span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista De Admisiones De Grado</span><br/><span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> jvtorres@utpl.edu.ec</span><br/><span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 3075</span></td></tr></table></div></td>
# </tr>
# </table></td>
# </tr>
# </table>
# <p> </p>
# </section>
# <footer class="footer_template">
# <div class="wrap">
# <div class="info_u">
# <table class="table_template">
# <tr>
# <td>
# <div class="cont_icon">
# <img class="img_template" src="images/telef.png"/>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									07 370 1444
# 								</div>
# <div class="txt_info">
# 									Comunícate con nuestros<br/>
# 									Docentes y Personal UTPL
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="http://www.utpl.edu.ec/buzon/" id="url_img" target="_blank"><img class="img_template" src="images/print.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Buzón de consultas
# 								</div>
# <div class="txt_info">
# 									Escríbenos a nuestro buzón y recibe una completa información de trámites y servicios UTPL.
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="http://www.utpl.edu.ec/centros_utpl/" id="url_img" target="_blank"><img class="img_template" src="images/marcador.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Centros UTPL
# 								</div>
# <div class="txt_info">
# 									Conoce el centro UTPL más cercano.
# 								</div>
# </div>
# </td>
# </tr>
# <tr>
# <td>
# <div class="cont_icon">
# <img class="img_template" src="images/audif.png"/>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									1800 8875 88
# 								</div>
# <div class="txt_info">
# 									En la línea gratuita 1800 podrás tener información de la oferta académica.
# 								</div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="https://tramites.utpl.edu.ec" id="url_img" target="_blank"><img class="img_template" src="images/mouse.png"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									Trámites académicos en línea
# 								</div>
# <div class="txt_info">
# 									Recuerda puedes ingresar tu Trámite académico en línea <a href="http://bit.ly/trámitesenlínea" id="url" target="_blank">http://bit.ly/trámitesenlínea</a><br/>
# </div>
# </div>
# </td>
# <td>
# <div class="cont_icon">
# <a href="#" id="url_img" target="_blank"><img class="img_template" src="images/app-movil.png" style="width:50px !important"/></a>
# </div>
# <div class="cont_txt">
# <div class="txt_titulo">
# 									App UTPL
# 								</div>
# <div class="txt_info">
# 									Descárgala en App Store para dispositivos iOS y en Google Play para Android.<br/>
# </div>
# </div>
# </td>
# <!--<td>
# 							<div class="cont_icon">
# 								<a href="http://www.utpl.edu.ec/academia/ebooks" id="url_img" target="_blank"><img src="images/ebook.png" class="img_template"></a>
# 							</div>
# 							<div class="cont_txt">
# 								<div class="txt_titulo">
# 									Soporte técnico para Ebooks y Tablets
# 								</div>
# 								<div class="txt_info">
# 									Comunícate con nosotros al 07 3701444<br> ext.: 3200 o escríbenos a ebooks@utpl.edu.ec<br>
# 								</div>
# 							</div>
# 						</td>-->
# </tr>
# </table>
# </div> </div>
# </footer>
# <footer class="subfooter">
# <div class="wrap">
# <p id="txt_subfoot">Sede Central Loja: el personal UTPL puede consultar la guía de usuario del servicio de comunicaciones unificadas en: <a href="http://bit.ly/1s4hUvW" id="lnk_guia" target="_blank">http://bit.ly/1s4hUvW.</a></p>
# </div>
# </footer>
# </body>
# </html>

# %%
names_sp = soup.findAll("span", {"class": "letra_nombre"});
spans_sp = soup.findAll("span", {"class": "letra_info"});

# %%
spans_sp
# Out:
# [<span class="letra_info"><img height="19" src="images/dep.gif" width="17"> Vicerrectora Académica</img></span>,
#  <span class="letra_info"><img height="19" src="images/mail.gif" width="17"> rrivas@utpl.edu.ec</img></span>,
#  <span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2349</span>,
#  <span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Analista de Desarrollo y Adaptación Curricular - Vicerrectorado Académico </span>,
#  <span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> mdrodas@utpl.edu.ec</span>,
#  <span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 3136</span>,
#  <span class="letra_info"><img height="19" src="images/dep.gif" width="17"/> Secretaria  De Dirección -  Vicerrectorado Académico</span>,
#  <span class="letra_info"><img height="19" src="images/mail.gif" width="17"/> caaguilar5@utpl.edu.ec</span>,
#  <span class="letra_info"><img height="19" src="images/fono.gif" width="17"/> 2349</span>]

# %%
names = []
emails = []
ext = []
dep = []

# %%
for i in names_sp:
    #name = i.find("span",{"class": "letra_nombre"})
    print(i.text)
    names.append(i.text)
# Out:
# De Rivas Manzano Maria Del Rosario, Ph.D.
# Rodas Tobar Maria Dolores, Mgtr.
# Aguilar Jumbo Cecilia Angelica, Mgtr.

# %%
for i in spans:
    em = i.find("img", {"src": "images/mail.gif"})
    if em is not None:
        print(em.text)
        emails.append(em.text)
# Out:
#  rrivas@utpl.edu.ec

# %%
for i in spans:
    em = i.find("img", {"src": "images/fono.gif"})
    if em is not None:
        print(em.text)
        ext.append(em.text)

# %%
for i in spans:
    em = i.find("img", {"src": "images/dep.gif"})
    if em is not None:
        print(em.text)
        dep.append(em.text)
# Out:
#  Vicerrectora Académica

# %%
json_f = {}
json_f['people'] = [] 
for i in names:
    json_f['people'].append({
        'name': i
    })

# %%
json_f
# Out:
# {'people': [{'name': 'De Rivas Manzano Maria Del Rosario, Ph.D.'},
#   {'name': 'Rodas Tobar Maria Dolores, Mgtr. '},
#   {'name': 'Aguilar Jumbo Cecilia Angelica, Mgtr. '}]}

# %%
with open('data.json', 'w') as file:
    json.dump(json_f, file, indent=4)

# %%
for info in items:  # print headers2
    h2 = info.find("h2")
    if h2:
        print(h2.text)
# Out:
# ¡Decididos en hacer historia! #50AñosUTPL
# Oferta académica
# Otros programas
# Tipos de becas
# Descuentos y formas de pago:
# ¿Por qué confiar en la UTPL?
# Prestigio internacional
# Enlaces de interés

# %% [markdown]
# ## Extracción de preguntas-respuestas sobre COVID
#
# Source: CNN FAQ's[https://edition.cnn.com/interactive/2020/health/coronavirus-questions-answers/]

# %%
import urllib
import re
import json
import os
import csv
import re
from datetime import date


def download(url, user_agent='Mozilla/5.0', num_retries=2):
    #Descarga una url. En caso de existir errores errores [500 600], intentar nuevamente.
    #Función adaptada desde (Lawson Richard, 2015)
    print('Descargando: ', url)
    headers = {'User-agent': user_agent}
    request = urllib.request.Request(url, headers=headers)
    try:
        html = urllib.request.urlopen(request).read()
    except urllib.error.URLError as e:
        print('Error descargando:', e.reason)
        html = None
        if num_retries > 0:
            if hasattr(e, 'code') and 500 <= e.code < 600:
                return download(url, user_agent, num_retries-1)
    return html

# %%
_page = 'https://edition.cnn.com/interactive/2020/health/coronavirus-questions-answers/'
_date = ''
regex = re.compile(r'[\n\r\t]')
QA_cnn = []
html = download(_page) 
soup = BeautifulSoup(html,"html.parser")
# find_all devuelve una lista con todas las etiquetas que cumplan la clase que se indica
blocksQ = soup.find_all(class_="question-q")  # en esta clase están todas las preguntas, 
blocksA = soup.find_all(class_="question-a") # en esta clase están todas las respuestas
blocksC = soup.find_all(class_="question-t")  # en esta clase están todas las categorías de preguntas
lenQA = len(blocksQ)
for i in range(lenQA):
    blocksc = blocksC[i].find_all(name="span")
    blocksc = [c.text for c in blocksc] # obtener el texto de cada categoría
    blocksc = ";".join(blocksc) # una pregunta puede tener varias categorías por tanto se unifican los valores
    #print(blocksQ[i])
    QA_cnn.append([date.today().strftime("%d/%m/%Y"), _page, blocksc, blocksQ[i].text, blocksA[i].text])
# Out:
# Descargando:  https://edition.cnn.com/interactive/2020/health/coronavirus-questions-answers/
# <div class="question-q">Is it safe to go on vacation?</div>
# <div class="question-q">If I already had Covid-19, should I still get vaccinated?</div>
# <div class="question-q">Could I get coronavirus from the Covid-19 vaccine?</div>
# <div class="question-q">How good are these vaccines? Why should I get a Johnson &amp; Johnson vaccine if the numbers don’t seem as good as the others?</div>
# <div class="question-q">How long will immunity last after getting a Covid-19 vaccine?</div>
# <div class="question-q">I have to go back to the office, and we need a babysitter. How do I keep my family safe with someone new in the house?</div>
# <div class="question-q">When can kids get vaccinated?</div>
# <div class="question-q">How long will we have to keep wearing masks?</div>
# <div class="question-q">What can I do after I’m vaccinated?</div>
# <div class="question-q">Can I travel after I get vaccinated?</div>
# <div class="question-q">Will Americans be required to get a Covid-19 vaccine? What happens if I don’t get vaccinated?</div>
# <div class="question-q">How much does a Covid-19 vaccine cost?</div>
# <div class="question-q">I know vaccines help prevent people from getting *sick* with coronavirus. But do they also prevent people from *carrying* the virus and infecting others?</div>
# <div class="question-q">What are the side effects of the vaccines?</div>
# <div class="question-q">When can I get a vaccine?</div>
# <div class="question-q">What are the long-term effects of coronavirus?</div>
# <div class="question-q">What is aerosolized spread? What’s the difference between aerosols and droplets?</div>
# <div class="question-q">This pandemic is taking a toll on my mental health. How can I get help if I’m feeling isolated and depressed?</div>
# <div class="question-q">Could I have the flu and coronavirus at the same time? If so, what does that do to your body?</div>
# <div class="question-q">How can I tell if I have coronavirus or the flu (or both)?</div>
# <div class="question-q">How long does immunity last if you recover from Covid-19? Are you immune for life?</div>
# <div class="question-q">What “underlying conditions” put people at higher risk of bad outcomes with Covid-19?</div>
# <div class="question-q">What are the guidelines for riding in a car with someone from another household?</div>
# <div class="question-q">What should I do if I’m wearing a mask but have to sneeze?</div>
# <div class="question-q">Are coronavirus and Covid-19 the same thing? How did they get their names?</div>
# <div class="question-q">If a pregnant woman gets Covid-19, will her baby be infected? Can babies get coronavirus through breastfeeding?</div>
# <div class="question-q">Can someone who died from coronavirus still have their organs donated?</div>
# <div class="question-q">Should we clean our cell phones daily?</div>
# <div class="question-q">Is it safe to go back to the gym?</div>
# <div class="question-q">I tested positive for coronavirus weeks ago. How long are people contagious with Covid-19? Do I need to keep isolating or getting retested?</div>
# <div class="question-q">I heard you can get Covid-19 through your eyes. Should we wear goggles, too?</div>
# <div class="question-q">Should people wear face shields instead of (or in addition to) face masks?</div>
# <div class="question-q">Doesn’t the flu kill more people than coronavirus?</div>
# <div class="question-q">Is it true that kids aren’t big spreaders of coronavirus? How much do children get Covid-19?</div>
# <div class="question-q">My kids don’t want to wear a mask. What should I do?</div>
# <div class="question-q">How do I prevent my glasses or sunglasses from fogging up when I wear a mask?</div>
# <div class="question-q">Are cancer patients at higher risk of severe complications from Covid-19?</div>
# <div class="question-q">Can central air conditioning spread Covid-19 in public places?</div>
# <div class="question-q">What does asymptomatic mean?</div>
# <div class="question-q">How effective are different types of face masks? Which cloth masks work the best?</div>
# <div class="question-q">Do I still need to quarantine for 14 days after returning from travel?</div>
# <div class="question-q">What’s so different about coronavirus that made us shut down the economy? Why do we have to practice social distancing now, when we didn’t during the SARS and swine flu epidemics?</div>
# <div class="question-q">When are people with coronavirus most contagious?</div>
# <div class="question-q">Can you get Covid-19 through sex?</div>
# <div class="question-q">Is it true young people with coronavirus are also having blood clots and strokes?</div>
# <div class="question-q">Why has the guidance on wearing face masks changed so much?</div>
# <div class="question-q">How can I stay safe in an elevator?</div>
# <div class="question-q">How safe are public restrooms?</div>
# <div class="question-q">Is hand sanitizer as effective as soap and water in killing coronavirus?</div>
# <div class="question-q">Are some blood types able to fight coronavirus better than other blood types?</div>
# <div class="question-q">What’s the risk of having a maid service come to clean your house if you’re not home?</div>
# <div class="question-q">Can I disinfect my mask by putting it in the microwave?</div>
# <div class="question-q">Is it safe to perform CPR on a stranger?</div>
# <div class="question-q">Can I get coronavirus from swimming in open water, like in a lake or seawater? What about in a public pool or hot tub?</div>
# <div class="question-q">I see other countries spraying down sidewalks and other public places with disinfectant. Why don’t we do that in the US?</div>
# <div class="question-q">Will protests increase the spread of Covid-19?</div>
# <div class="question-q">Do vitamin D levels affect your risk for coronavirus? Is there a correlation between vitamin D and those who test positive for Covid-19?</div>
# <div class="question-q">Can you get coronavirus from touching money? What about from other objects, like plants?</div>
# <div class="question-q">Can you get coronavirus by touching a dead body or the ashes of someone who had Covid-19?</div>
# <div class="question-q">Can UV light kill coronavirus?</div>
# <div class="question-q">Do I need to wash fruits and vegetables with soap and water?</div>
# <div class="question-q">Can coronavirus stay in my hair or in a beard? Should I wash my hair every day?</div>
# <div class="question-q">Could I infect my pets with coronavirus, or vice versa? Can someone get infected by touching an animal’s fur? Should I get my pet tested for coronavirus?</div>
# <div class="question-q">What is contact tracing?</div>
# <div class="question-q">Should I wash my hands and laundry in very warm or hot water?</div>
# <div class="question-q">How does soap kill coronavirus? If I don’t have disinfecting wipes, can I use soap and water on surfaces?</div>
# <div class="question-q">Can coronavirus be transferred by people’s shoes? How do I protect kids who crawl or play on the floor?</div>
# <div class="question-q">Can I get coronavirus through food? Is it safe to eat takeout from restaurants?</div>
# <div class="question-q">Can coronavirus spread through water, like in a swimming pool or hot tub?</div>
# <div class="question-q">Can mosquitoes or houseflies transmit coronavirus?</div>
# <div class="question-q">Can you safely reuse a non-cloth mask that you can’t wash, like a disposable mask?</div>
# <div class="question-q">Will ingesting or injecting disinfectants, like the ones that kill viruses on surfaces, protect me against coronavirus or kill coronavirus if I already have it?</div>
# <div class="question-q">What can we learn from how other countries handled coronavirus?</div>
# <div class="question-q">Can coronavirus stick to clothes? Do I need to wash my clothes right after encountering other people, like at the grocery store or while jogging?</div>
# <div class="question-q">Will an antibody test show whether I’m immune and can go back to work or school?</div>
# <div class="question-q">Can I use vodka as hand sanitizer?</div>
# <div class="question-q">Are smokers or vapers at higher risk? What if I only smoke weed?</div>
# <div class="question-q">My teenagers aren’t taking this seriously. Any advice?</div>
# <div class="question-q">Does this pandemic have anything to do with the 5G network?</div>
# <div class="question-q">My ex and I have joint custody of our kids. Is it safe for them to go between two homes?</div>
# <div class="question-q">How long does coronavirus stay “alive” on surfaces?</div>
# <div class="question-q">Will a pneumonia or flu vaccine help protect against coronavirus?</div>
# <div class="question-q">Should I wear a face mask in public? If so, how do I make one?</div>
# <div class="question-q">Why is it so difficult to make a drug to cure coronavirus?</div>
# <div class="question-q">Why are medical workers getting sick with or dying from coronavirus if they’re wearing protective gear? Does the viral load matter?</div>
# <div class="question-q">How many people with coronavirus don't have symptoms? Are they still contagious?</div>
# <div class="question-q">If there’s no cure, why go to the hospital unless you have a breathing problem?</div>
# <div class="question-q">Why are people stocking up on bottled water? Is the water supply at risk?</div>
# <div class="question-q">How do I safely take care of someone who’s sick?</div>
# <div class="question-q">What are the symptoms?</div>
# <div class="question-q">What can I do if my loved one thinks he or she has coronavirus?</div>
# <div class="question-q">Should I disinfect my groceries? If so, how?</div>
# <div class="question-q">The stores are all out of disinfectant sprays and hand sanitizer. Can I make my own?</div>
# <div class="question-q">Should I stock up on extra food and supplies?</div>
# <div class="question-q">Should I avoid public transportation?</div>
# <div class="question-q">Can I be fired if I stay home sick?</div>
# <div class="question-q">What happens when workers don't get paid sick leave?</div>
# <div class="question-q">Can managers send a sick worker home?</div>
# <div class="question-q">If traveling on a plane, how do I stay safe?</div>
# <div class="question-q">Since a plane's cabin keeps circulating air, will I get sick if another passenger is sick?</div>
# <div class="question-q">If I have a weakened immune system, should I cancel my travel plans?</div>
# <div class="question-q">What do I do if I think I’m sick?</div>
# <div class="question-q">What’s the best way to prevent getting infected?</div>
# <div class="question-q">Should I spray myself or my kids with disinfectant?</div>
# <div class="question-q">I’ve heard that home remedies can cure or prevent the virus. Is that true?</div>
# <div class="question-q">Why waste a test kit on a person without symptoms?</div>
# <div class="question-q">Why has the US been so far behind other countries with testing?</div>
# <div class="question-q">If a coronavirus patient gets pneumonia, what antibiotics have proven to be effective?</div>
# <div class="question-q">Did Dean Koontz predict this outbreak in the book “The Eyes of Darkness” almost 40 years ago?</div>
# <div class="question-q">Can the heat from a hand dryer kill coronavirus?</div>
# <div class="question-q">Can I get coronavirus from a package sent from China?</div>

# %%
# Guardar QA pairs:
fields = ['date', 'url', 'category', 'question', 'answer']
with open('data/cnn_qapairs.csv','w') as f:
    w = csv.writer(f, quoting=csv.QUOTE_ALL, quotechar='"')
    w.writerow(fields)
    w.writerows(QA_cnn)
